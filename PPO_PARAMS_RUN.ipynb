# %% [markdown]
# <a href="https://colab.research.google.com/github/Davidmenamm/Reinforcement-Learning---PPO-Algorithm-Communication/blob/main/PPO_PARAMS_RUN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PPO PARAMS - All Algorithms**

# %% [markdown]
# # **Config**

# %% [markdown]
# ## Google Drive Mount

# %%
# Connect to Google Drive Files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install Dependencies

# %%
# Install Dependencies
! pip install gymnasium
! pip install pymunk
! pip install lz4

# box 2d dependency
! pip install swig
! pip install xvfbwrapper
! pip install pyvirtualdisplay

# pettingzoo
! pip install pettingzoo[all]

# jax parallel
! pip install jaxlib==0.4.26 -f https://storage.googleapis.com/jax-releases/jax_releases.html
! pip install jax-dataclasses
! pip install cflib

# ray
! pip install ray


# experiments
! pip install supersuit


# SUPRESS PRINT FOR A RUN, COMMENT IF WANT TO SEE PRINTS IN CONSOLE
# sys.stdout = open(os.devnull, 'w')
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pymunk in /usr/local/lib/python3.10/dist-packages (6.2.0)
# Requirement already satisfied: cffi>1.14.0 in /usr/local/lib/python3.10/dist-packages (from pymunk) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>1.14.0->pymunk) (2.22)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (4.2.1)
# Requirement already satisfied: xvfbwrapper in /usr/local/lib/python3.10/dist-packages (0.2.9)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: pettingzoo[all] in /usr/local/lib/python3.10/dist-packages (1.24.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (1.26.4)
# Requirement already satisfied: gymnasium>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (1.0.0)
# Requirement already satisfied: multi-agent-ale-py==0.1.11 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (0.1.11)
# Requirement already satisfied: pygame==2.3.0 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (2.3.0)
# Requirement already satisfied: chess==1.9.4 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (1.9.4)
# Requirement already satisfied: rlcard==1.0.5 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (1.0.5)
# Requirement already satisfied: shimmy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (2.0.0)
# Requirement already satisfied: pymunk==6.2.0 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (6.2.0)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (2.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (1.13.1)
# Requirement already satisfied: pillow>=8.0.1 in /usr/local/lib/python3.10/dist-packages (from pettingzoo[all]) (10.4.0)
# Requirement already satisfied: cffi>1.14.0 in /usr/local/lib/python3.10/dist-packages (from pymunk==6.2.0->pettingzoo[all]) (1.17.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from rlcard==1.0.5->pettingzoo[all]) (2.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->pettingzoo[all]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->pettingzoo[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->pettingzoo[all]) (0.0.4)
# Requirement already satisfied: open-spiel>=1.2 in /usr/local/lib/python3.10/dist-packages (from shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (1.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>1.14.0->pymunk==6.2.0->pettingzoo[all]) (2.22)
# Requirement already satisfied: pip>=20.0.2 in /usr/local/lib/python3.10/dist-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (24.1.2)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (24.2.0)
# Requirement already satisfied: absl-py>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (1.4.0)
# Requirement already satisfied: ml-collections>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (0.1.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from ml-collections>=0.1.1->open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (6.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ml-collections>=0.1.1->open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (1.16.0)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from ml-collections>=0.1.1->open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (21.6.0)
# Looking in links: https://storage.googleapis.com/jax-releases/jax_releases.html
# Collecting jaxlib==0.4.26
#   Using cached jaxlib-0.4.26-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jaxlib==0.4.26) (1.13.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from jaxlib==0.4.26) (1.26.4)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jaxlib==0.4.26) (0.4.1)
# Using cached jaxlib-0.4.26-cp310-cp310-manylinux2014_x86_64.whl (78.8 MB)
# Installing collected packages: jaxlib
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.33
#     Uninstalling jaxlib-0.4.33:
#       Successfully uninstalled jaxlib-0.4.33
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.87 requires jaxlib>=0.4.27, but you have jaxlib 0.4.26 which is incompatible.
# jax 0.4.33 requires jaxlib<=0.4.33,>=0.4.33, but you have jaxlib 0.4.26 which is incompatible.
# optax 0.2.3 requires jaxlib>=0.4.27, but you have jaxlib 0.4.26 which is incompatible.
# Successfully installed jaxlib-0.4.26
# Requirement already satisfied: jax-dataclasses in /usr/local/lib/python3.10/dist-packages (1.6.1)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from jax-dataclasses) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from jax-dataclasses) (0.4.26)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from jax-dataclasses) (4.12.2)
# Collecting jaxlib (from jax-dataclasses)
#   Using cached jaxlib-0.4.33-cp310-cp310-manylinux2014_x86_64.whl.metadata (983 bytes)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->jax-dataclasses) (0.4.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from jax->jax-dataclasses) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->jax-dataclasses) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->jax-dataclasses) (1.13.1)
# Using cached jaxlib-0.4.33-cp310-cp310-manylinux2014_x86_64.whl (85.0 MB)
# Installing collected packages: jaxlib
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.26
#     Uninstalling jaxlib-0.4.26:
#       Successfully uninstalled jaxlib-0.4.26
# Successfully installed jaxlib-0.4.33
# Requirement already satisfied: cflib in /usr/local/lib/python3.10/dist-packages (0.1.26)
# Requirement already satisfied: pyusb>=1.0.0b2 in /usr/local/lib/python3.10/dist-packages (from cflib) (1.2.1)
# Requirement already satisfied: libusb-package~=1.0 in /usr/local/lib/python3.10/dist-packages (from cflib) (1.0.26.2)
# Requirement already satisfied: scipy~=1.7 in /usr/local/lib/python3.10/dist-packages (from cflib) (1.13.1)
# Requirement already satisfied: numpy~=1.20 in /usr/local/lib/python3.10/dist-packages (from cflib) (1.26.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from libusb-package~=1.0->cflib) (6.4.5)
# Requirement already satisfied: ray in /usr/local/lib/python3.10/dist-packages (2.37.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray) (1.0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray) (24.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray) (2.32.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (2024.8.30)
# Requirement already satisfied: supersuit in /usr/local/lib/python3.10/dist-packages (3.9.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from supersuit) (1.26.4)
# Requirement already satisfied: gymnasium>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from supersuit) (1.0.0)
# Requirement already satisfied: tinyscaler>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from supersuit) (1.2.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.1->supersuit) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.1->supersuit) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.1->supersuit) (0.0.4)

# %% [markdown]
# ## Imports

# %%
# Import libraries
import os
import sys
import time
import yaml
import numpy as np
from datetime import datetime, timedelta
import ray
from ray.tune import run
from ray.tune.registry import register_env
from ray.rllib.env.wrappers.pettingzoo_env import PettingZooEnv, ParallelPettingZooEnv
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from ray.rllib.env.multi_agent_episode import MultiAgentEpisode
from ray.rllib.algorithms.ppo import (
    PPOConfig,
    PPOTF1Policy,
    PPOTF2Policy,
    PPOTorchPolicy,
)
from ray import air, tune
from ray.air.constants import TRAINING_ITERATION
from ray.rllib.utils.metrics import (
    ENV_RUNNER_RESULTS,
    EPISODE_RETURN_MEAN,
    NUM_ENV_STEPS_SAMPLED_LIFETIME,
)
from gymnasium.spaces import Box
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.models.tf.tf_modelv2 import TFModelV2
from ray.rllib.models.tf.fcnet import FullyConnectedNetwork
from ray.rllib.models.torch.misc import SlimFC
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.torch.fcnet import FullyConnectedNetwork as TorchFC
from ray.rllib.utils.annotations import override
from ray.rllib.utils.framework import try_import_tf, try_import_torch
# pettingzoo envs
from pettingzoo.sisl import pursuit_v4, multiwalker_v9, waterworld_v4
from pettingzoo.butterfly import pistonball_v6

# %% [markdown]
# ## Robotic Envs

# %%
# Clone CrazyRL repository and install it
# !git clone https://github.com/ffelten/CrazyRL.git
os.chdir("CrazyRL")
# !poetry install
os.chdir("..")

# Add CrazyRL directory to PYTHONPATH
crazy_rl_dir = os.path.abspath("CrazyRL")
if crazy_rl_dir not in sys.path:
    sys.path.append(crazy_rl_dir)

# Import personalized env
import crazy_rl
from crazy_rl.multi_agent.numpy.catch.catch import Catch
from crazy_rl.multi_agent.numpy.hover.hover import Hover
from crazy_rl.multi_agent.numpy.circle.circle import Circle
from crazy_rl.multi_agent.numpy.surround.surround import Surround
# Out:
# fatal: destination path 'CrazyRL' already exists and is not an empty directory.
# /bin/bash: line 1: poetry: command not found

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Environments to Run

# %%
# environments to run
envs_to_run = {
    "Hover": ("mlp", True),
    "Circle": ("mlp", True),
    # "Pursuit": ("cnn", False),
    # "Multiwalker": ("cnn", False)
}

# %% [markdown]
# ## PPO Params

# %% [markdown]
# ### Mlp module

# %%
import json
from pathlib import Path

# base param path
params_base_path = "/content/drive/My Drive/PPO/CONFIG/"

# PPO params
ppo_params_path = f'{params_base_path}ppo_params.json'
ppo_params = json.loads(Path(ppo_params_path).read_text())
ppo_params
# Out:
# {'lr': 0.0001,
#  'use_critic': True,
#  'use_gae': True,
#  'lambda_': 0.95,
#  'num_sgd_iter': 7,
#  'train_batch_size': 4096,
#  'sgd_minibatch_size': 1024,
#  'entropy_coeff': 0.01,
#  'vf_loss_coeff': 0.3,
#  'clip_param': 0.1,
#  'vf_clip_param': 10.0,
#  'grad_clip': 0.4,
#  'kl_coeff': 0.2,
#  'kl_target': 0.01,
#  'shuffle_sequences': True}

# %% [markdown]
# ### Cnn module

# %%
# PPO params cnn
ppo_params_cnn_path = f'{params_base_path}ppo_params_cnn.json'
ppo_params_cnn = json.loads(Path(ppo_params_cnn_path).read_text())
ppo_params_cnn
# Out:
# {'model': {'uses_new_env_runners': True},
#  'lr': 0.0001,
#  'use_critic': True,
#  'use_gae': True,
#  'lambda_': 0.95,
#  'num_sgd_iter': 7,
#  'train_batch_size': 4096,
#  'sgd_minibatch_size': 1024,
#  'entropy_coeff': 0.01,
#  'vf_loss_coeff': 0.3,
#  'clip_param': 0.1,
#  'vf_clip_param': 10.0,
#  'grad_clip': 0.4,
#  'kl_coeff': 0.2,
#  'kl_target': 0.01,
#  'shuffle_sequences': True}

# %% [markdown]
# ## Workspace Params

# %%
# PPO params
workspace_params_path = f'{params_base_path}workspace_params.json'
workspace_params = json.loads(Path(workspace_params_path).read_text())
workspace_params
# Out:
# {'num_workers': 10,
#  'num_envs_per_worker': -1,
#  'episode_aprox_length': -1,
#  'max_episodes': -1,
#  'verbosity': -1}

# %% [markdown]
# ## Environment Params Path and Formatting

# %%
# env params paths
drone_hover_params_path = f'{params_base_path}drone_hover_params.json'
target_catch_params_path = f'{params_base_path}target_catch_params.json'
target_surround_params_path = f'{params_base_path}target_surround_params.json'
target_circle_params_path = f'{params_base_path}target_circle_params.json'
pursuit_params_path = f'{params_base_path}pursuit_params.json'
multiwalker_params_path = f'{params_base_path}multiwalker_params.json'
waterworld_params_path = f'{params_base_path}waterworld_params.json'
pistonball_params_path = f'{params_base_path}pistonball_params.json'

# Make lists to numpy arr for robotic envs
def lists_to_np_arrays(d):
    return {k: np.array(v) if isinstance(v, list) else v for k, v in d.items()}

# %% [markdown]
# ## Drone Hover params

# %%
# drone hover
drone_hover_params = lists_to_np_arrays( json.loads(Path(drone_hover_params_path).read_text()) )
drone_hover_params
# Out:
# {'init_flying_pos': array([[2, 0, 0],
#         [1, 2, 0]]),
#  'drone_ids': array([0, 1]),
#  'size': 3,
#  'render_mode': None}

# %% [markdown]
# ## Target Catch params

# %%
# target catch
target_catch_params = lists_to_np_arrays( json.loads(Path(target_catch_params_path).read_text()) )
target_catch_params
# Out:
# {'drone_ids': array([0, 1]),
#  'init_flying_pos': array([[2, 2, 0],
#         [2, 2, 2]]),
#  'init_target_location': array([1. , 1. , 2.5]),
#  'render_mode': None,
#  'target_speed': 0.1,
#  'size': 3}

# %% [markdown]
# ## Target Surround params

# %%
# target surround
target_surround_params = lists_to_np_arrays( json.loads(Path(target_surround_params_path).read_text()) )
target_surround_params
# Out:
# {'drone_ids': array([0, 1]),
#  'init_flying_pos': array([[0, 1, 2],
#         [0, 0, 1]]),
#  'target_location': array([1. , 1. , 2.5]),
#  'target_id': None,
#  'render_mode': None,
#  'size': 3,
#  'multi_obj': False}

# %% [markdown]
# ## Target Circle params

# %%
# target circle
target_circle_params = lists_to_np_arrays( json.loads(Path(target_circle_params_path).read_text()) )
target_circle_params
# Out:
# {'init_flying_pos': array([[1, 1, 1],
#         [0, 0, 1]]),
#  'drone_ids': array([0, 1]),
#  'render_mode': None,
#  'num_intermediate_points': 100,
#  'size': 3}

# %% [markdown]
# ## Pursuit params

# %%
# pursuit
pursuit_params = json.loads(Path(pursuit_params_path).read_text())
pursuit_params
# Out:
# {'max_cycles': 500,
#  'render_mode': 'rgb_array',
#  'x_size': 20,
#  'y_size': 20,
#  'shared_reward': True,
#  'n_evaders': 6,
#  'n_pursuers': 2,
#  'obs_range': 7,
#  'n_catch': 2,
#  'freeze_evaders': False,
#  'tag_reward': 0.01,
#  'catch_reward': 5.0,
#  'urgency_reward': -0.1,
#  'surround': True,
#  'constraint_window': 1.0}

# %% [markdown]
# ## Multiwalker params

# %%
# multiwalker
multiwalker_params = json.loads(Path(multiwalker_params_path).read_text())
multiwalker_params
# Out:
# {'n_walkers': 2,
#  'position_noise': 0.001,
#  'angle_noise': 0.001,
#  'forward_reward': 1.0,
#  'terminate_reward': -40.0,
#  'fall_reward': -4.0,
#  'shared_reward': False,
#  'terminate_on_fall': True,
#  'remove_on_fall': True,
#  'terrain_length': 200,
#  'max_cycles': 500,
#  'render_mode': 'rgb_array'}

# %% [markdown]
# ## Waterworld params

# %%
# waterworld
waterworld_params = json.loads(Path(waterworld_params_path).read_text())
waterworld_params
# Out:
# {'max_cycles': 500,
#  'n_coop': 2,
#  'n_sensors': 20,
#  'sensor_range': 0.2,
#  'radius': 0.015,
#  'obstacle_radius': 0.2,
#  'n_obstacles': 1,
#  'obstacle_coord': [[0.5, 0.5]],
#  'pursuer_max_accel': 0.1,
#  'evader_speed': 0.1,
#  'poison_speed': 0.1,
#  'thrust_penalty': -1.0,
#  'local_ratio': 1.0,
#  'speed_features': True,
#  'n_pursuers': 2,
#  'n_evaders': 4,
#  'n_poisons': 4,
#  'poison_reward': -10.0,
#  'food_reward': 20.0,
#  'encounter_reward': 0.5,
#  'render_mode': 'rgb_array'}

# %% [markdown]
# ## Pistonball params

# %%
# pistonball
pistonball_params = json.loads(Path(pistonball_params_path).read_text())
pistonball_params
# Out:
# {'render_mode': 'rgb_array',
#  'n_pistons': 10,
#  'time_penalty': -0.1,
#  'continuous': True,
#  'random_drop': True,
#  'random_rotate': True,
#  'ball_mass': 0.75,
#  'ball_friction': 0.3,
#  'ball_elasticity': 1.5,
#  'max_cycles': 125}

# %% [markdown]
# # Setup Environments

# %%
# Environment creator
def env_creator(config):
    # Create corresponding env
    envs = {
        # robotic envs
        'Hover' : (lambda: Hover(**drone_hover_params), True),
        'Catch' : (lambda: Catch(**target_catch_params), True),
        'Surround' : (lambda: Surround(**target_surround_params), True),
        'Circle' : (lambda: Circle(**target_circle_params), True),
        # regular envs
        'Pursuit' : (lambda: pursuit_v4.env(**pursuit_params), False),
        'Multiwalker' : (lambda: multiwalker_v9.env(**multiwalker_params), False),
        'Waterworld' : (lambda: waterworld_v4.env(**waterworld_params), False),
        'Pistonball' : (lambda: pistonball_v6.env(**pistonball_params), False),
    }
    print(config["name"])
    # Create environment with params
    environment, is_parallel = envs[config["name"]]
    environment_call = environment()
    # Return env
    return environment_call, is_parallel

# Get environment specifications (obs space, act space, etc)
def get_specification(config):
    # current env
    current_env, is_parallel = env_creator(config)
    print(current_env)
    # init observation
    init_obs = current_env.reset()
    # agents and spaces
    agents = current_env.agents
    obs_space = current_env.observation_space(agents[0])
    act_space = current_env.action_space(agents[0])
    # return
    return obs_space, act_space, agents, is_parallel

# Register environment
def register_environment(env_name):
    # register env
    env_name_config = {"name": env_name}
    # dummy env specifications
    obs_space, act_space, agents, is_parallel = get_specification(env_name_config)
    if is_parallel:
        register_env(f"{env_name}", lambda config: ParallelPettingZooEnv(env_creator(env_name_config)[0]))
    else:
        register_env(f"{env_name}", lambda config: PettingZooEnv(env_creator(env_name_config)[0]))
    # return env specifications
    return obs_space, act_space, agents

# Register available environments and save specifications
envs_specifications = {}
for env in envs_to_run.keys():
    obs_space, act_space, agents = register_environment(env)
    envs_specifications[env] = (obs_space, act_space, agents)

# print specifications in console
envs_specifications
# Out:
# Hover
# Hover
# Circle
# Circle
# {'Hover': (Box([-3. -3.  0. -3. -3.  0.], 3.0, (6,), float32),
#   Box(-1.0, 1.0, (3,), float32),
#   ['agent_0', 'agent_1']),
#  'Circle': (Box([-3. -3.  0. -3. -3.  0.], 3.0, (6,), float32),
#   Box(-1.0, 1.0, (3,), float32),
#   ['agent_0', 'agent_1'])}

# %% [markdown]
# # Init Ray Ecosystem

# %%
# Ray ecosystem initialization
ray.init(local_mode=True, ignore_reinit_error=True)
# Out:
# 2024-10-15 14:33:45,437	INFO worker.py:1786 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.37.0', ray_commit='1b620f244c4fb67d80661046091573fb6eefecb6')

# %% [markdown]
# # Callback & Metrics

# %% [markdown]
# ## Config & Paths

# %%
# Ensure the directory exists
def ensure_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory, exist_ok=True)

# time now
timeNow = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %% [markdown]
# ## Callbacks

# %%
# Custom Callback
class CustomCallback(DefaultCallbacks):
    def __init__(self, env_name, algo_mode):
        self.env_name = env_name
        # variables
        self.start_time = time.time()
        self.episode_num = 1
        self.delta_timestep = 0
        self.delta_timestep_sum = 0
        # base dir
        base_log_dir = f"/content/drive/My Drive/PPO/{algo_mode}/"
        # env dirs
        env_dirs = {
            "Hover": f'{base_log_dir}Hover/rrun_{timeNow}',
            "Catch": f'{base_log_dir}Catch/rrun_{timeNow}',
            "Surround": f'{base_log_dir}Surround/rrun_{timeNow}',
            "Circle": f'{base_log_dir}Circle/rrun_{timeNow}',
            "Pursuit": f'{base_log_dir}Pursuit/rrun_{timeNow}',
            "Multiwalker": f'{base_log_dir}Multiwalker/rrun_{timeNow}',
            "Waterworld": f'{base_log_dir}Waterworld/rrun_{timeNow}',
            "Pistonball": f'{base_log_dir}Pistonball/rrun_{timeNow}'
        }
        # inside dirs
        fileEpisodes = f"episodes_{timeNow}.txt"
        fileRewards = f"episode_rewards_{timeNow}.txt"
        fileTime = f"time_{timeNow}.txt"
        # Ensure the log directories exists
        ensure_dir(base_log_dir)
        for env in env_dirs.values():
            ensure_dir(env)

        # Env dirs
        self.log_dir = env_dirs[env_name]
        self.episode_num_log = os.path.join(self.log_dir, fileEpisodes)
        self.episode_reward_log = os.path.join(self.log_dir, fileRewards)
        self.episode_time_log = os.path.join(self.log_dir, fileTime)

        # erase previous content
        with open(self.episode_num_log , 'w') as f:
            f.write(f"{self.env_name}\n")
        with open(self.episode_reward_log , 'w') as f:
            f.write(f"{self.env_name}\n")

    # on episode end
    def on_episode_end(
        self,
        *,
        worker,
        base_env,
        policies,
        episode: MultiAgentEpisode,
        **kwargs
    ):
        print('BASE-ENV', self.env_name)
        episode_reward_total_sum = sum(episode.agent_rewards.values())

        try:
            # Timer
            def elapsed_time(start_time):
                current_time = time.time()
                elapsed_seconds = current_time - start_time
                elapsed_minutes = elapsed_seconds / 60
                elapsed_hours = elapsed_minutes / 60
                return elapsed_hours, elapsed_minutes

            # Delta time
            if self.episode_num == 1:
                self.delta_timestep = (elapsed_time(self.start_time)[1]) / workspace_params["num_workers"]
            if self.episode_num < 20+1:
                self.delta_timestep_sum += elapsed_time(self.start_time)[1]
            if self.episode_num == 20:
                self.delta_timestep = self.delta_timestep_sum / self.episode_num
                self.delta_timestep_sum = 0

            minutes_time_remaining = workspace_params["max_episodes"]* self.delta_timestep - self.episode_num * self.delta_timestep
            hours_time_remaining = minutes_time_remaining / 60

            # Log future time
            with open(self.episode_time_log, 'a') as f:
                elapsed_hours, elapsed_minutes = elapsed_time(self.start_time)
                f.write(
                    f"""
                    \nEpisode {self.episode_num} / {workspace_params["max_episodes"]}
                    Elapsed Time: {elapsed_hours:.2f} hours ({elapsed_minutes:.2f} minutes)
                    Approximate missing time {hours_time_remaining:.2f} hours ({minutes_time_remaining:.2f} minutes)
                    """
                )
                f.flush()  # Force the flush to disk after write
                print(f"Logged time for episode {self.episode_num}")

            # Save episodes in file
            with open(self.episode_num_log, 'a') as f:
                f.write(f"{self.episode_num}\n")
                f.flush()  # Force flush
                print(f"Logged episode number {self.episode_num}")

            # Sum episode num
            self.episode_num += 1

            # Save reward in file
            with open(self.episode_reward_log, 'a') as f:
                f.write(f"{episode_reward_total_sum}\n")
                f.flush()  # Force flush
                print(f"Logged reward for episode {self.episode_num - 1}: {episode_reward_total_sum}")

        except Exception as e:
            print(f"Failed to write episode reward: {e}")

# %% [markdown]
# # Tuning & Training

# %%
# modes
modes = ['parameters', 'multiple']  # , 'centralized']

# run envs
for mode in modes:
    for env_name, setup in envs_to_run.items():
        base_model, old_stack = setup
        print('params ', mode, env_name, base_model, old_stack)

        # BASE CONFIG
        config = (
            PPOConfig()
            .framework("torch")
            .env_runners(batch_mode="complete_episodes", num_env_runners=workspace_params['num_workers'])
            .training( **(ppo_params if base_model == "mlp" else ppo_params_cnn) )
        )

        # STACK
        # new stack
        if old_stack:
            config = (
                config.environment(f"{env_name}")
                .resources(num_gpus=int(os.environ.get("RLLIB_NUM_GPUS", "0")), num_cpus_per_worker=1)
            )
        # old stack
        else:
            _, _, agents = envs_specifications[env_name]
            config = (
                config.environment("env_1", env_config={"num_agents": len(agents)})
                .resources(num_gpus=int(os.environ.get("RLLIB_NUM_GPUS", "0")))
                .api_stack(enable_rl_module_and_learner=True, enable_env_runner_and_connector_v2=True)
                .learners(num_learners=1, num_gpus_per_learner=1)
            )

        # TYPE OF MODEL
        if base_model == "cnn":
            config = (
                config.rl_module(
                    model_config_dict={
                        "uses_new_env_runners": True,
                        "vf_share_layers": False,
                        "use_lstm": False,
                        "fcnet_hiddens": [128, 128],
                        "conv_filters": [[7, 7, 3], [32, 4, 2], [64, 8, 1]],
                    }
                )
            )

        # MODE
        if mode == "parameters":
            # callbacks
            config = (
                config.callbacks(lambda: CustomCallback(env_name, 'Parameters'))
            )
        elif mode == "multiple":
            # Multi-agent configuration
            obs_space, act_space, agents = envs_specifications[env_name]

            # Generate policies
            def gen_policy(i):
                return (None, obs_space, act_space, {})

            # Assigned policies to each agent
            policies = {"policy_{}".format(i): gen_policy(i) for i in range(len(agents))}

            # Policies mapping function
            def policy_mapping_fn(agent_id, *args, **kwargs):
                policy_ids = list(policies.keys())
                return policy_ids[agents.index(agent_id)]

            # env name
            print("env_name", env_name)

            # config
            config = (
                config.multi_agent(
                    policy_mapping_fn=policy_mapping_fn,
                    policies=policies
                )
                .callbacks(lambda: CustomCallback(env_name, 'Independent'))
            )

        # print config
        print('config', config.to_dict())

        # STOP CONDITIONS
        stop = {
            TRAINING_ITERATION: 10,
            # "num_env_steps_sampled_lifetime": 100000,
            # f"{ENV_RUNNER_RESULTS}/{EPISODE_RETURN_MEAN}": 7.99,
        }

        # TUNING
        tuner = tune.Tuner(
            "PPO",
            param_space=config.to_dict(),
            run_config=air.RunConfig(stop=stop, verbose=1),
        )

        # RESULTS
        results = tuner.fit()
        print(results)

    # Optionally, the previous run approach
    # run(
    #   'PPO',
    #   config=config,
    #   checkpoint_freq=10,
    #   checkpoint_at_end=True,
    #   verbose=3,
    #   stop={"episodes_total": 10000},
    #   reuse_actors=True,
    # )
# Out:
# 2024-10-15 14:33:46,590	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.resources(num_cpus_per_worker)` has been deprecated. Use `AlgorithmConfig.env_runners(num_cpus_per_env_runner)` instead. This will raise an error in the future!
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# 2024-10-15 14:33:46,637	INFO tensorboardx.py:193 -- pip install "ray[tune]" to see TensorBoard files.
# 2024-10-15 14:33:46,638	WARNING callback.py:136 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# params  parameters Hover mlp True
# config {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'enable_rl_module_and_learner': False, 'enable_env_runner_and_connector_v2': False, 'env': 'Hover', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 10, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1, 'num_gpus_per_env_runner': 0, 'custom_resources_per_env_runner': {}, 'validate_env_runners_after_construction': True, 'sample_timeout_s': 60.0, '_env_to_module_connector': None, 'add_default_connectors_to_env_to_module_pipeline': True, '_module_to_env_connector': None, 'add_default_connectors_to_module_to_env_pipeline': True, 'episode_lookback_horizon': 1, 'rollout_fragment_length': 'auto', 'batch_mode': 'complete_episodes', 'compress_observations': False, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'enable_tf1_exec_eagerly': False, 'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>, 'preprocessor_pref': 'deepmind', 'observation_filter': 'NoFilter', 'update_worker_filter_stats': True, 'use_worker_filter_stats': True, 'enable_connectors': True, 'sampler_perf_stats_ema_coef': None, 'num_learners': 0, 'num_gpus_per_learner': 0, 'num_cpus_per_learner': 1, 'local_gpu_idx': 0, 'gamma': 0.99, 'lr': 0.0001, 'grad_clip': 0.4, 'grad_clip_by': 'global_norm', 'train_batch_size_per_learner': None, 'train_batch_size': 4096, 'model': {'_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [256, 256], 'fcnet_activation': 'tanh', 'fcnet_weights_initializer': None, 'fcnet_weights_initializer_config': None, 'fcnet_bias_initializer': None, 'fcnet_bias_initializer_config': None, 'conv_filters': None, 'conv_activation': 'relu', 'conv_kernel_initializer': None, 'conv_kernel_initializer_config': None, 'conv_bias_initializer': None, 'conv_bias_initializer_config': None, 'conv_transpose_kernel_initializer': None, 'conv_transpose_kernel_initializer_config': None, 'conv_transpose_bias_initializer': None, 'conv_transpose_bias_initializer_config': None, 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'post_fcnet_weights_initializer': None, 'post_fcnet_weights_initializer_config': None, 'post_fcnet_bias_initializer': None, 'post_fcnet_bias_initializer_config': None, 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, 'lstm_weights_initializer': None, 'lstm_weights_initializer_config': None, 'lstm_bias_initializer': None, 'lstm_bias_initializer_config': None, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position ...
# +------------------------------------------------------------+
# | Configuration for experiment     PPO_2024-10-15_14-33-46   |
# +------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator     |
# | Scheduler                        FIFOScheduler             |
# | Number of trials                 1                         |
# +------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/PPO_2024-10-15_14-33-46
# :job_id:01000000
# :task_name:bundle_reservation_check_func
# :actor_name:PPO
# :job_id:01000000
# :task_name:bundle_reservation_check_func
# :actor_name:PPO
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# Hover
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# :actor_name:RolloutWorker
# 2024-10-15 14:33:48,044	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Hover
# :actor_name:PPO
#
# Trial PPO_Hover_7c7a3_00000 started with configuration:
# +---------------------------------------------------------------------------+
# | Trial PPO_Hover_7c7a3_00000 config                                        |
# +---------------------------------------------------------------------------+
# | _AlgorithmConfig__prior_exploration_config                                |
# | _disable_action_flattening                                          False |
# | _disable_execution_plan_api                                            -1 |
# | _disable_initialize_loss_from_dummy_batch                           False |
# | _disable_preprocessor_api                                           False |
# | _dont_auto_sync_env_runner_states                                   False |
# | _enable_rl_module_api                                                  -1 |
# | _env_to_module_connector                                                  |
# | _evaluation_parallel_to_training_wo_thread                          False |
# | _fake_gpus                                                          False |
# | _is_atari                                                                 |
# | _learner_class                                                            |
# | _learner_connector                                                        |
# | _module_to_env_connector                                                  |
# | _rl_module_spec                                                           |
# | _run_training_always_in_thread                                      False |
# | _tf_policy_handles_more_than_one_loss                               False |
# | _torch_grad_scaler_class                                                  |
# | _torch_lr_scheduler_classes                                               |
# | action_mask_key                                               action_mask |
# | action_space                                                              |
# | actions_in_input_normalized                                         False |
# | add_default_connectors_to_env_to_module_pipeline                     True |
# | add_default_connectors_to_learner_pipeline                           True |
# | add_default_connectors_to_module_to_env_pipeline                     True |
# | always_attach_evaluation_results                                       -1 |
# | auto_wrap_old_gym_envs                                                 -1 |
# | batch_mode                                              complete_episodes |
# | callbacks                                            ...t 0x799818978670> |
# | checkpoint_trainable_policies_only                                  False |
# | clip_actions                                                        False |
# | clip_param                                                            0.1 |
# | clip_rewards                                                              |
# | compress_observations                                               False |
# | count_steps_by                                                  env_steps |
# | create_env_on_driver                                                False |
# | custom_async_evaluation_function                                       -1 |
# | custom_eval_function                                                      |
# | dataset_num_iters_per_learner                                             |
# | delay_between_env_runner_restarts_s                                   60. |
# | disable_env_checking                                                False |
# | eager_max_retraces                                                     20 |
# | eager_tracing                                                        True |
# | enable_async_evaluation                                                -1 |
# | enable_connectors                                                    True |
# | enable_env_runner_and_connector_v2                                  False |
# | enable_rl_module_and_learner                                        False |
# | enable_tf1_exec_eagerly                                             False |
# | entropy_coeff                                                        0.01 |
# | entropy_coeff_schedule                                                    |
# | env                                                                 Hover |
# | env_runner_cls                                                            |
# | env_runner_health_probe_timeout_s                                      30 |
# | env_runner_restore_timeout_s                                         1800 |
# | env_task_fn                                                               |
# | episode_lookback_horizon                                                1 |
# | evaluation_config                                                         |
# | evaluation_duration                                                    10 |
# | evaluation_duration_unit                                         episodes |
# | evaluation_force_reset_envs_before_iteration                         True |
# | evaluation_interval                                                       |
# | evaluation_num_env_runners                                              0 |
# | evaluation_parallel_to_training                                     False |
# | evaluation_sample_timeout_s                                          120. |
# | exploration_config/type                                StochasticSampling |
# | explore                                                              True |
# | export_native_model_files                                           False |
# | fake_sampler                                                        False |
# | framework                                                           torch |
# | gamma                                                                0.99 |
# | grad_clip                                                             0.4 |
# | grad_clip_by                                                  global_norm |
# | ignore_env_runner_failures                                          False |
# | in_evaluation                                                       False |
# | input                                                             sampler |
# | input_compress_columns                                 ['obs', 'new_obs'] |
# | input_filesystem                                                          |
# | input_read_episodes                                                 False |
# | input_read_method                                            read_parquet |
# | input_read_sample_batches                                           False |
# | input_spaces_jsonable                                                True |
# | keep_per_episode_custom_metrics                                     False |
# | kl_coeff                                                              0.2 |
# | kl_target                                                            0.01 |
# | lambda                                                               0.95 |
# | local_gpu_idx                                                           0 |
# | local_tf_session_args/inter_op_parallelism_threads                      8 |
# | local_tf_session_args/intra_op_parallelism_threads                      8 |
# | log_level                                                            WARN |
# | log_sys_usage                                                        True |
# | logger_config                                                             |
# | logger_creator                                                            |
# | lr                                                                 0.0001 |
# | lr_schedule                                                               |
# | max_num_env_runner_restarts                                          1000 |
# | max_requests_in_flight_per_sampler_worker                               2 |
# | metrics_episode_collection_timeout_s                                  60. |
# | metrics_num_episodes_for_smoothing                                    100 |
# | min_sample_timesteps_per_iteration                                      0 |
# | min_time_s_per_iteration                                                  |
# | min_train_timesteps_per_iteration                                       0 |
# | mini_batch_size_per_learner                                               |
# | model/_disable_action_flattening                                    False |
# | model/_disable_preprocessor_api                                     False |
# | model/_time_major                                                   False |
# | model/_use_default_native_models                                       -1 |
# | model/always_check_shapes                                           False |
# | model/attention_dim                                                    64 |
# | model/attention_head_dim                                               32 |
# | model/attention_init_gru_gate_bias                                    2.0 |
# | model/attention_memory_inference                                       50 |
# | model/attention_memory_training                                        50 |
# | model/attention_num_heads                                               1 |
# | model/attention_num_transformer_units                                   1 |
# | model/attention_position_wise_mlp_dim                                  32 |
# | model/attention_use_n_prev_actions                                      0 |
# | model/attention_use_n_prev_rewards                                      0 |
# | model/conv_activation                                                relu |
# | model/conv_bias_initializer                                               |
# | model/conv_bias_initializer_config                                        |
# | model/conv_filters                                                        |
# | model/conv_kernel_initializer                                             |
# | model/conv_kernel_initializer_config                                      |
# | model/conv_transpose_bias_initializer                                     |
# | model/conv_transpose_bias_initializer_config                              |
# | model/conv_transpose_kernel_initializer                                   |
# | model/conv_transpose_kernel_initializer_config                            |
# | model/custom_action_dist                                                  |
# | model/custom_model                                                        |
# | model/custom_preprocessor                                                 |
# | model/dim                                                              84 |
# | model/encoder_latent_dim                                                  |
# | model/fcnet_activation                                               tanh |
# | model/fcnet_bias_initializer                                              |
# | model/fcnet_bias_initializer_config                                       |
# | model/fcnet_hiddens                                            [256, 256] |
# | model/fcnet_weights_initializer                                           |
# | model/fcnet_weights_initializer_config                                    |
# | model/framestack                                                     True |
# | model/free_log_std                                                  False |
# | model/grayscale                                                     False |
# | model/lstm_bias_initializer                                               |
# | model/lstm_bias_initializer_config                                        |
# | model/lstm_cell_size                                                  256 |
# | model/lstm_use_prev_action                                          False |
# | model/lstm_use_prev_action_reward                                      -1 |
# | model/lstm_use_prev_reward                                          False |
# | model/lstm_weights_initializer                                            |
# | model/lstm_weights_initializer_config                                     |
# | model/max_seq_len                                                      20 |
# | model/no_final_linear                                               False |
# | model/post_fcnet_activation                                          relu |
# | model/post_fcnet_bias_initializer                                         |
# | model/post_fcnet_bias_initializer_config                                  |
# | model/post_fcnet_hiddens                                               [] |
# | model/post_fcnet_weights_initializer                                      |
# | model/post_fcnet_weights_initializer_config                               |
# | model/use_attention                                                 False |
# | model/use_lstm                                                      False |
# | model/vf_share_layers                                               False |
# | model/zero_mean                                                      True |
# | normalize_actions                                                    True |
# | num_consecutive_env_runner_failures_tolerance                         100 |
# | num_cpus_for_main_process                                               1 |
# | num_cpus_per_env_runner                                                 1 |
# | num_cpus_per_learner                                                    1 |
# | num_env_runners                                                        10 |
# | num_envs_per_env_runner                                                 1 |
# | num_gpus                                                                0 |
# | num_gpus_per_env_runner                                                 0 |
# | num_gpus_per_learner                                                    0 |
# | num_learners                                                            0 |
# | num_sgd_iter                                                            7 |
# | observation_filter                                               NoFilter |
# | observation_fn                                                            |
# | observation_space                                                         |
# | offline_sampling                                                    False |
# | ope_split_batch_by_episode                                           True |
# | output                                                                    |
# | output_compress_columns                                ['obs', 'new_obs'] |
# | output_filesystem                                                         |
# | output_max_file_size                                             67108864 |
# | output_max_rows_per_file                                                  |
# | output_write_episodes                                                True |
# | output_write_method                                         write_parquet |
# | placement_strategy                                                   PACK |
# | policies/default_policy                              ...None, None, None) |
# | policies_to_train                                                         |
# | policy_map_cache                                                       -1 |
# | policy_map_capacity                                                   100 |
# | policy_mapping_fn                                    ...t 0x79981d83e170> |
# | policy_states_are_swappable                                         False |
# | postprocess_inputs                                                  False |
# | prelearner_class                                                          |
# | prelearner_module_synch_period                                         10 |
# | preprocessor_pref                                                deepmind |
# | recreate_failed_env_runners                                         False |
# | remote_env_batch_wait_ms                                                0 |
# | remote_worker_envs                                                  False |
# | render_env                                                          False |
# | replay_sequence_length                                                    |
# | restart_failed_sub_environments                                     False |
# | rollout_fragment_length                                              auto |
# | sample_collector                                     ...leListCollector'> |
# | sample_timeout_s                                                      60. |
# | sampler_perf_stats_ema_coef                                               |
# | seed                                                                      |
# | sgd_minibatch_size                                                   1024 |
# | shuffle_buffer_size                                                     0 |
# | shuffle_sequences                                                    True |
# | simple_optimizer                                                       -1 |
# | sync_filters_on_rollout_workers_timeout_s                             10. |
# | synchronize_filters                                                    -1 |
# | tf_session_args/allow_soft_placement                                 True |
# | tf_session_args/device_count/CPU                                        1 |
# | tf_session_args/gpu_options/allow_growth                             True |
# | tf_session_args/inter_op_parallelism_threads                            2 |
# | tf_session_args/intra_op_parallelism_threads                            2 |
# | tf_session_args/log_device_placement                                False |
# | torch_compile_learner                                               False |
# | torch_compile_learner_dynamo_backend                             inductor |
# | torch_compile_learner_dynamo_mode                                         |
# | torch_compile_learner_what_to_compile                ...ile.FORWARD_TRAIN |
# | torch_compile_worker                                                False |
# | torch_compile_worker_dynamo_backend                                onnxrt |
# | torch_compile_worker_dynamo_mode                                          |
# | torch_skip_nan_gradients                                            False |
# | train_batch_size                                                     4096 |
# | train_batch_size_per_learner                                              |
# | update_worker_filter_stats                                           True |
# | use_critic                                                           True |
# | use_gae                                                              True |
# | use_kl_loss                                                          True |
# | use_worker_filter_stats                                              True |
# | validate_env_runners_after_construction                              True |
# | vf_clip_param                                                         10. |
# | vf_loss_coeff                                                         0.3 |
# | vf_share_layers                                                        -1 |
# | worker_cls                                                             -1 |
# +---------------------------------------------------------------------------+
# :actor_name:PPO
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -6.171397539920196
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -4.652869980297892
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -5.407157445082735
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -8.893116090807537
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -4.650318109455629
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -8.347770587164892
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -4.036171563635468
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -8.65700025769169
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -5.677045808659803
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -6.415004551361752
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -5.199838469393589
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -6.501353240078762
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -7.239938952268595
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -7.756428599779869
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -8.280344047321865
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -11.044171887290158
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -8.856569508193324
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -9.252805802599939
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -9.270735559873941
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -7.309479539433476
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -4.896951060657434
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -9.24463427370705
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -6.297986346099872
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -8.023218410332376
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -4.104375094150601
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -6.407947251261058
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -7.8516884835640415
# BASE-ENV Hover
# Logged time for episode 1
# Logged episode number 1
# Logged reward for episode 1: -10.393788974104153
# BASE-ENV Hover
# Logged time for episode 2
# Logged episode number 2
# Logged reward for episode 2: -9.934379711307493
# BASE-ENV Hover
# Logged time for episode 3
# Logged episode number 3
# Logged reward for episode 3: -7.971824134621695
#
# Trial status: 1 RUNNING
# Current time: 2024-10-15 14:34:03. Total running time: 16s
# Logical resource usage: 11.0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:L4)
# +----------------------------------+
# | Trial name              status   |
# +----------------------------------+
# | PPO_Hover_7c7a3_00000   RUNNING  |
# +----------------------------------+
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -5.108190372617494
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -10.55393311676228
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -6.685490565023289
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -5.744245821596108
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -6.140250687617005
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -7.286465443447433
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -6.93591340931213
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -7.9609993517814335
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -9.671268643403401
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -5.381263699818225
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -7.349385242478212
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -7.958667436969781
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -8.530379335852178
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -8.839049230964905
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -5.411546843352842
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -6.041718214125213
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -4.445393715868721
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -4.817600196715306
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -5.497023024811517
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -7.124417919918134
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -5.888088901803923
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -3.722157513334487
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -6.844888633352296
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -6.16529770700084
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -5.878574475440756
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -3.6900270157382895
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -4.818324108003397
# BASE-ENV Hover
# Logged time for episode 4
# Logged episode number 4
# Logged reward for episode 4: -5.266988943448161
# BASE-ENV Hover
# Logged time for episode 5
# Logged episode number 5
# Logged reward for episode 5: -6.271366866725307
# BASE-ENV Hover
# Logged time for episode 6
# Logged episode number 6
# Logged reward for episode 6: -5.260769500317008
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -6.270943640135567
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -5.681155900936487
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -6.201122531510167
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -3.5398657088611882
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -5.930719018481579
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -2.0333154719682787
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -7.747388173058346
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -5.778293385311628
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -4.292448234149229
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -3.5388306994180656
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -4.576939062382096
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -2.7766126873648567
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -4.428957107002775
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -5.942753383967112
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -4.653478534831026
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -6.926458877166057
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -3.7711144835263326
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -5.800809843636532
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -6.085551447857008
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -6.91987774452087
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -3.977333193021237
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -4.537296030479084
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -7.431036042880162
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -3.454653540152879
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -4.514967062667194
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -4.599678453751503
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -6.928649983734283
# BASE-ENV Hover
# Logged time for episode 7
# Logged episode number 7
# Logged reward for episode 7: -3.9422545908169586
# BASE-ENV Hover
# Logged time for episode 8
# Logged episode number 8
# Logged reward for episode 8: -5.1532481068899525
# BASE-ENV Hover
# Logged time for episode 9
# Logged episode number 9
# Logged reward for episode 9: -7.918612079530321
# Trial status: 1 RUNNING
# Current time: 2024-10-15 14:34:33. Total running time: 46s
# Logical resource usage: 11.0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:L4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name              status       iter     total time (s)     ts     num_healthy_workers     ...async_sample_reqs     ...e_worker_restarts     ...ent_steps_sampled |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_Hover_7c7a3_00000   RUNNING         2            30.4311   8400                      10                        0                        0                    16800 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -4.3727571808735215
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -8.878048685904744
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -3.1058563392225693
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -5.309107427439899
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -6.307707562003879
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -3.0548499507023
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -2.5642829478047227
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -6.038291777718898
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -3.1510499681555295
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -3.6721126264093558
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -4.19071158992417
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -5.5581047276561915
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -4.923948428989651
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -4.711433919367712
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -4.504681270178525
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -5.799774913005254
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -6.738798053980465
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -8.355386078512932
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -2.5234739778095268
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -5.6768144283143
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -8.264925966297852
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -4.96624128185425
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -5.03385283572773
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -5.670199045845502
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -4.202205931637103
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -6.7809109306558675
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -5.523398205463911
# BASE-ENV Hover
# Logged time for episode 10
# Logged episode number 10
# Logged reward for episode 10: -7.09464559910475
# BASE-ENV Hover
# Logged time for episode 11
# Logged episode number 11
# Logged reward for episode 11: -8.162148387859087
# BASE-ENV Hover
# Logged time for episode 12
# Logged episode number 12
# Logged reward for episode 12: -5.34157925252616
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -5.015870355657312
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -4.873787310800989
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -8.654853214509181
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -3.2883955437850716
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -4.708448900338145
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -4.1236161345607645
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -2.7534057896513215
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -4.520284700074891
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -4.616379465810981
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -2.091242223703672
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -7.83235137517406
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -5.852893959704385
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -2.8748973395531783
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -4.943733899991445
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -5.830514822925396
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -5.832432548572832
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -6.4539101187598575
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -6.239825984055552
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -6.103997055638205
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -5.117286749612864
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -6.808633806103524
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -3.4846150415318347
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -4.770744584560761
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -6.311829854194966
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -7.360001975562014
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -5.24768296977125
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -4.312499057514591
# BASE-ENV Hover
# Logged time for episode 13
# Logged episode number 13
# Logged reward for episode 13: -4.810449761047019
# BASE-ENV Hover
# Logged time for episode 14
# Logged episode number 14
# Logged reward for episode 14: -2.292028164358533
# BASE-ENV Hover
# Logged time for episode 15
# Logged episode number 15
# Logged reward for episode 15: -4.002477938719514
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -6.382578595765812
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -5.727665509933684
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -5.179070120035021
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -4.463140641401967
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -5.010490579849842
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -5.942023938319551
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -2.2857697134377113
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -4.307332557697777
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -5.869450517847767
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -2.085320015045575
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -5.249387829316568
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -3.9520757439141505
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -4.749781475946929
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -4.665468554495455
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -3.0229918502383826
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -5.817312600651529
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -5.15273892301048
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -5.7027129738631
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -7.089083040024718
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -4.716791785253385
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -6.0199961054272535
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -2.3299152185744916
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -5.9990488457361355
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -6.301599360840006
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -1.1042770412656187
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -5.9924595668550085
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -5.833086106596513
# BASE-ENV Hover
# Logged time for episode 16
# Logged episode number 16
# Logged reward for episode 16: -6.184486938987859
# BASE-ENV Hover
# Logged time for episode 17
# Logged episode number 17
# Logged reward for episode 17: -4.711269715755977
# BASE-ENV Hover
# Logged time for episode 18
# Logged episode number 18
# Logged reward for episode 18: -7.869617411836128
# Trial status: 1 RUNNING
# Current time: 2024-10-15 14:35:17. Total running time: 1min 31s
# ...
# Logged reward for episode 24: 5.233061733468796
# BASE-ENV Circle
# Logged time for episode 22
# Logged episode number 22
# Logged reward for episode 22: 5.716214033750907
# BASE-ENV Circle
# Logged time for episode 23
# Logged episode number 23
# Logged reward for episode 23: 4.9557515649869455
# BASE-ENV Circle
# Logged time for episode 24
# Logged episode number 24
# Logged reward for episode 24: 6.229587090690673
# BASE-ENV Circle
# Logged time for episode 22
# Logged episode number 22
# Logged reward for episode 22: 6.233289056618299
# BASE-ENV Circle
# Logged time for episode 23
# Logged episode number 23
# Logged reward for episode 23: 7.726577286833406
# BASE-ENV Circle
# Logged time for episode 24
# Logged episode number 24
# Logged reward for episode 24: 4.23638040197708
# BASE-ENV Circle
# Logged time for episode 22
# Logged episode number 22
# Logged reward for episode 22: 5.278063502667377
# BASE-ENV Circle
# Logged time for episode 23
# Logged episode number 23
# Logged reward for episode 23: 6.395917227857292
# BASE-ENV Circle
# Logged time for episode 24
# Logged episode number 24
# Logged reward for episode 24: 5.033479293852112
# BASE-ENV Circle
# Logged time for episode 22
# Logged episode number 22
# Logged reward for episode 22: 5.081447333847464
# BASE-ENV Circle
# Logged time for episode 23
# Logged episode number 23
# Logged reward for episode 23: 5.04602529471337
# BASE-ENV Circle
# Logged time for episode 24
# Logged episode number 24
# Logged reward for episode 24: 5.386576969820053
# BASE-ENV Circle
# Logged time for episode 22
# Logged episode number 22
# Logged reward for episode 22: 4.636625191854632
# BASE-ENV Circle
# Logged time for episode 23
# Logged episode number 23
# Logged reward for episode 23: 6.737750902649107
# BASE-ENV Circle
# Logged time for episode 24
# Logged episode number 24
# Logged reward for episode 24: 4.426836577139777
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 7.063112629427517
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 5.1721190119041385
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 5.864649394260019
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 8.484201347222399
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 5.32383154810228
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 3.775152219215088
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 6.401031128680653
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 4.760433385356746
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 6.411361923359982
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 7.816610707882367
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 6.915023943220884
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 5.535943725784702
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 6.749417558462701
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 6.613770428999853
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 5.743766296827879
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 6.197929868221307
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 7.120974949908231
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 6.04140475165766
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 6.269349025684816
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 4.54890018311275
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 6.888999828217723
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 5.176174762583092
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 6.058784631118231
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 7.1713649859271005
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 5.176947111568248
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 6.862384206862657
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 7.498925691438441
# BASE-ENV Circle
# Logged time for episode 25
# Logged episode number 25
# Logged reward for episode 25: 5.165207218114094
# BASE-ENV Circle
# Logged time for episode 26
# Logged episode number 26
# Logged reward for episode 26: 7.221670534957109
# BASE-ENV Circle
# Logged time for episode 27
# Logged episode number 27
# Logged reward for episode 27: 5.813823173451012
# Trial status: 1 RUNNING
# Current time: 2024-10-15 14:45:54. Total running time: 3min 19s
# Logical resource usage: 11.0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:L4)
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name               status       iter     total time (s)      ts     num_healthy_workers     ...async_sample_reqs     ...e_worker_restarts     ...ent_steps_sampled |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_Circle_b74f1_00000   RUNNING         8            176.982   33600                      10                        0                        0                    67200 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 6.594902356934925
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 7.527189435100419
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 7.642556140651211
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 7.287642980938252
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 7.825850968939962
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 6.638587035197958
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 5.331463311808561
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 7.637820590480134
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 5.414723313782606
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 7.656350273811331
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 6.720309055595896
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 7.251538448989146
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 6.980065566967591
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 7.170030953500691
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 7.386022630319888
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 6.135826486303687
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 7.481801617023919
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 6.163618479143957
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 5.821267417375431
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 6.126635478032664
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 7.05051449283873
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 6.710126178349034
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 7.550850970120933
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 6.151984676574572
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 7.199618024528204
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 6.543321873006569
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 7.121139253016916
# BASE-ENV Circle
# Logged time for episode 28
# Logged episode number 28
# Logged reward for episode 28: 6.556566428480535
# BASE-ENV Circle
# Logged time for episode 29
# Logged episode number 29
# Logged reward for episode 29: 6.403410271262959
# BASE-ENV Circle
# Logged time for episode 30
# Logged episode number 30
# Logged reward for episode 30: 7.211348118562068
# 2024-10-15 14:46:16,899	INFO storage.py:556 -- Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/PPO_2024-10-15_14-42-34/PPO_Circle_b74f1_00000_0_2024-10-15_14-42-34/checkpoint_000000)
# Trial PPO_Circle_b74f1_00000 completed after 10 iterations at 2024-10-15 14:46:16. Total running time: 3min 42s
# +-------------------------------------------------+
# | Trial PPO_Circle_b74f1_00000 result             |
# +-------------------------------------------------+
# | env_runners/episode_len_mean                200 |
# | env_runners/episode_return_mean         6.00269 |
# | num_env_steps_sampled_lifetime            42000 |
# +-------------------------------------------------+
# 2024-10-15 14:46:17,328	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/PPO_2024-10-15_14-42-34' in 0.0215s.
# Trial status: 1 TERMINATED
# Current time: 2024-10-15 14:46:17. Total running time: 3min 42s
# Logical resource usage: 0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:L4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name               status         iter     total time (s)      ts     num_healthy_workers     ...async_sample_reqs     ...e_worker_restarts     ...ent_steps_sampled |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_Circle_b74f1_00000   TERMINATED       10            221.019   42000                      10                        0                        0                    84000 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# ResultGrid<[
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_0': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.39929080980164666, 'cur_kl_coeff': 0.0003906250000000001, 'cur_lr': 9.999999999999999e-05, 'total_loss': -0.031655181269161406, 'policy_loss': -0.0058985358968909295, 'vf_loss': 0.05112096145749092, 'vf_explained_var': 0.36525763954435075, 'kl': 0.001710145090432239, 'entropy': 4.109360354287284, 'entropy_coeff': 0.01}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 840.0, 'num_grad_updates_lifetime': 333.0, 'diff_num_grad_updates_vs_sampler_policy': 17.0}, 'policy_1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.39923851507050656, 'cur_kl_coeff': 0.0003906250000000001, 'cur_lr': 9.999999999999999e-05, 'total_loss': -0.03196340501308441, 'policy_loss': -0.005542966543829866, 'vf_loss': 0.04975458841238703, 'vf_explained_var': 0.32914845091956, 'kl': 0.002090275388406683, 'entropy': 4.134763363429478, 'entropy_coeff': 0.01}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 840.0, 'num_grad_updates_lifetime': 333.0, 'diff_num_grad_updates_vs_sampler_policy': 17.0}}, 'num_env_steps_sampled': 42000, 'num_env_steps_trained': 42000, 'num_agent_steps_sampled': 84000, 'num_agent_steps_trained': 84000}, 'env_runners': {'episode_reward_max': 8.484201347222395, 'episode_reward_min': 2.8689274085204604, 'episode_reward_mean': 6.0026891482398, 'episode_len_mean': 200.0, 'episode_media': {}, 'episodes_timesteps_total': 20000, 'policy_reward_min': {'policy_0': 0.9968502869305231, 'policy_1': 0.9066615237329282}, 'policy_reward_max': {'policy_0': 4.644491182367015, 'policy_1': 4.800440753829793}, 'policy_reward_mean': {'policy_0': 2.90965159719793, 'policy_1': 3.093037551041869}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [5.448591455815601, 5.2529812609746696, 3.997503517299978, 3.9616475512422262, 6.203511844341167, 5.72162479415024, 3.8828178724944884, 4.3940004269809565, 7.3151412755763, 2.8689274085204604, 6.123219035717036, 5.071531917229332, 5.52743474650259, 6.50810727802571, 5.30413200039116, 6.38141880825867, 5.0273931142783574, 6.413920747184557, 5.314734589649599, 4.707192482666158, 2.917277659468833, 4.2382818242563145, 5.134555680598179, 3.0630350704616105, 5.233061733468791, 5.716214033750902, 4.955751564986944, 6.229587090690669, 6.233289056618297, 7.726577286833405, 4.236380401977076, 5.278063502667375, 6.3959172278572884, 5.033479293852121, 5.081447333847466, 5.046025294713369, 5.386576969820046, 4.636625191854643, 6.737750902649104, 4.426836577139771, 7.063112629427514, 5.172119011904135, 5.86464939426003, 8.484201347222395, 5.323831548102283, 3.7751522192150873, 6.4010311286806525, 4.76043338535675, 6.411361923359979, 7.816610707882375, 6.915023943220875, 5.535943725784702, 6.749417558462705, 6.6137704289998585, 5.743766296827879, 6.197929868221305, 7.1209749499082315, 6.0414047516576606, 6.269349025684819, 4.548900183112746, 6.888999828217724, 5.1761747625830905, 6.058784631118233, 7.171364985927104, 5.176947111568248, 6.862384206862651, 7.498925691438441, 5.165207218114095, 7.221670534957119, 5.813823173451008, 6.59490235693493, 7.5271894351004205, 7.642556140651223, 7.287642980938254, 7.825850968939964, 6.6385870351979595, 5.3314633118085615, 7.637820590480135, 5.414723313782609, 7.656350273811329, 6.720309055595896, 7.251538448989144, 6.980065566967587, 7.170030953500691, 7.386022630319882, 6.135826486303685, 7.481801617023916, 6.16361847914395, 5.821267417375435, 6.126635478032664, 7.050514492838736, 6.710126178349038, 7.55085097012093, 6.151984676574572, 7.199618024528204, 6.543321873006575, 7.12113925301691, 6.556566428480534, 6.403410271262961, 7.211348118562073], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200 ...
#     path='/root/ray_results/PPO_2024-10-15_14-42-34/PPO_Circle_b74f1_00000_0_2024-10-15_14-42-34',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/root/ray_results/PPO_2024-10-15_14-42-34/PPO_Circle_b74f1_00000_0_2024-10-15_14-42-34/checkpoint_000000)
#   )
# ]>
